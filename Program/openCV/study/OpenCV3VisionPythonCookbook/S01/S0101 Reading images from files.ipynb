# %% [markdown]
# # Reading Images from Files

# %%
#Let's import OpenCV module
import cv2

#Now we'll specify the path to our image
image_path = 'data/test.jpg'

#We'll use OpenCV's built-in function 'imread' to read the image
#Specify the image_path in the imread function
image = cv2.imread(image_path)

#If image is loaded successfully
#Go ahead and print the details
if image is not None:
    print('Image Loaded Successfully\n')

    #Let's check what kind of object 'image_path' is
    #We can do this using 'print' and 'type' functions
    print('\'image_path\t: ', type(image_path))

    #Let's check what data do we have in 'image' object
    #This should be a numpy array
    print('\'image\'\t\t: ', type(image))

    #Let's check what's the height and width of 'image'
    print('\nImage Height x Width: {0} x {1}'
          .format(image.shape[0], image.shape[1]))
    
    # %pylab inline
    plt.axis('off')
    plt.imshow(image[:,:,[2,1,0]],cmap='gray' )
    plt.show()
    
    cv2.imshow('Our First Frame', image)
    cv2.waitKey()
    cv2.destroyAllWindows()
# Out:
# Image Loaded Successfully
#
# 'image_path	:  <class 'str'>
# 'image'		:  <class 'numpy.ndarray'>
#
# Image Height x Width: 507 x 639
# Populating the interactive namespace from numpy and matplotlib

# %%
image = cv2.imread("data/Lena.png")

# Check if image was successfully read.
assert image is not None

print('read {}'.format("data/Lena.png"))
print('shape:', image.shape)
print('dtype:', image.dtype)

imageIMREAD_GRAYSCALE = cv2.imread("data/Lena.png", cv2.IMREAD_GRAYSCALE)
assert imageIMREAD_GRAYSCALE is not None
print('read {} as grayscale'.format("data/Lena.png"))
print('shape:', imageIMREAD_GRAYSCALE.shape)
print('dtype:', imageIMREAD_GRAYSCALE.dtype)

# %pylab inline
plt.subplot(1,2,1)
plt.axis('off')
plt.title("data/Lena.png")
plt.imshow(image[:,:,[2,1,0]],cmap='gray' )

plt.subplot(1,2,2)
plt.axis('off')
plt.title("cv2.IMREAD_GRAYSCALE")
plt.imshow(imageIMREAD_GRAYSCALE,cmap='gray' )
plt.show()
    
cv2.imshow('data/Lena.png', image)
cv2.imshow('cv2.IMREAD_GRAYSCALE', imageIMREAD_GRAYSCALE)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# read data/Lena.png
# shape: (512, 512, 3)
# dtype: uint8
# read data/Lena.png as grayscale
# shape: (512, 512)
# dtype: uint8
# Populating the interactive namespace from numpy and matplotlib
